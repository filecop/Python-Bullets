# %% [markdown]
# <a href="https://colab.research.google.com/github/filecop/Python-Bullets/blob/main/232224_SequentialDataTypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * Sequential data types refers to a class of data types that manage
# sequences of similar or different elements. The elements stored in
# sequential data types have a defined order, and they can be
# accessed through unique indexes
#
# * Python essentially provides the following five sequential types: str,
# bytes, bytearray, list, and tuple
#
# * ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Operations on Instances of Sequential Data Types
# * ![image.png](data:image/png;base64,...)
#
# * ![image.png](data:image/png;base64,...)

# %% [markdown]
# * ![image.png](data:image/png;base64,...)

# %%
#Checking for elements :lst = ["one", 2, 3.0, "four", 5, "six", "seven"]
lst = ["one", 2, 3.0, "four", 5, "six", "seven"]
3.0 in lst
"four" in lst
10 in lst
# Out:
# False
